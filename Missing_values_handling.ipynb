# %% [markdown]
# <a href="https://colab.research.google.com/github/Bimal999/python/blob/main/Missing_values_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1g1nwk4k-h9FceEHKZc8ocfu_xp3xnZ8R
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1g1nwk4k-h9FceEHKZc8ocfu_xp3xnZ8R
# To: /content/hr.csv
# 100% 580k/580k [00:00<00:00, 107MB/s]

# %%
import pandas as pd

df=pd.read_csv('hr.csv')

# %%
df.head(50)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.24             0.79               2                   175
# 1                 0.40             0.49               2                   155
# 2                 0.45             0.45               2                   154
# 3                 0.46             0.73               6                   256
# 4                 0.14             0.54               5                   275
# 5                 0.62             0.52               3                   148
# 6                 0.66             0.56               4                   141
# 7                 0.58             0.57               3                   144
# 8                 0.60             0.91               4                   185
# 9                 0.42             0.52               2                   141
# 10                0.11             0.88               7                   272
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        15004.000000     15004.000000    15004.000000
# mean             0.612871         0.716096        3.802919
# std              0.248628         0.171163        1.232550
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          15004.000000        15004.000000   15004.000000
# mean             201.044655            3.497934       0.144561
# std               49.937662            1.460012       0.351670
# min               96.000000            2.000000       0.000000
# 25%              156.000000            3.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15004 entries, 0 to 15003
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     15004 non-null  float64
#  1   last_evaluation        15004 non-null  float64
#  2   number_project         15004 non-null  int64
#  3   average_montly_hours   15004 non-null  int64
#  4   time_spend_company     15004 non-null  int64
#  5   Work_accident          15004 non-null  int64
#  6   left                   15004 non-null  object
#  7   promotion_last_5years  15004 non-null  int64
#  8   Department             15004 non-null  object
#  9   salary                 14975 non-null  object
#  10  age                    3080 non-null   float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (15004, 11)

# %%
df.isnull().sum()
# Out:
# satisfaction_level           0
# last_evaluation              0
# number_project               0
# average_montly_hours         0
# time_spend_company           0
# Work_accident                0
# left                         0
# promotion_last_5years        0
# Department                   0
# salary                      29
# age                      11924
# dtype: int64

# %%
print(df.isnull())
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                   False            False           False
# 1                   False            False           False
# 2                   False            False           False
# 3                   False            False           False
# 4                   False            False           False
# ...                   ...              ...             ...
# 14999               False            False           False
# 15000               False            False           False
# 15001               False            False           False
# 15002               False            False           False
# 15003               False            False           False
#
#        average_montly_hours  time_spend_company  Work_accident   left  \
# 0                     False               False          False  False
# 1                     False               False          False  False
# ...

# %% [markdown]
# # Fill missing values in 'age' column with the mean

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.24             0.79               2                   175
# 1                0.40             0.49               2                   155
# 2                0.45             0.45               2                   154
# 3                0.46             0.73               6                   256
# 4                0.14             0.54               5                   275
#
#    time_spend_company  Work_accident left  promotion_last_5years   Department  \
# 0                   5              0    0                      0           IT
# 1                   3              0    1                      0           hr
# 2                   3              1    1                      0      support
# 3                   4              0    0                      0  product_mng
# 4                   4              1    0                      0        sales
#
#    salary   age
# 0     low   NaN
# ...

# %%
mean_age = df['age'].mean()
df['age'].fillna(mean_age, inplace=True)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.24             0.79               2                   175
# 1                0.40             0.49               2                   155
# 2                0.45             0.45               2                   154
# 3                0.46             0.73               6                   256
# 4                0.14             0.54               5                   275
#
#    time_spend_company  Work_accident left  promotion_last_5years   Department  \
# 0                   5              0    0                      0           IT
# 1                   3              0    1                      0           hr
# 2                   3              1    1                      0      support
# 3                   4              0    0                      0  product_mng
# 4                   4              1    0                      0        sales
#
#    salary        age
# ...

# %% [markdown]
# # Fill missing values in 'Department' column with the mode

# %%
mode_department = df['Department'].mode()[0]  # mode() returns a series, so we take the first value
df['Department'].fillna(mode_department, inplace=True)

# %% [markdown]
# # Fill missing values in 'salary' column with the mode

# %%
mode_salary = df['salary'].mode()[0]
df['salary'].fillna(mode_salary, inplace=True)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.24             0.79               2                   175
# 1                0.40             0.49               2                   155
# 2                0.45             0.45               2                   154
# 3                0.46             0.73               6                   256
# 4                0.14             0.54               5                   275
#
#    time_spend_company  Work_accident left  promotion_last_5years   Department  \
# 0                   5              0    0                      0           IT
# 1                   3              0    1                      0           hr
# 2                   3              1    1                      0      support
# 3                   4              0    0                      0  product_mng
# 4                   4              1    0                      0        sales
#
#    salary        age
# ...
